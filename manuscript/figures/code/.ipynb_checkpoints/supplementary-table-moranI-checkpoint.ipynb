# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib
import geopandas as gpd
import jenkspy
from datetime import datetime, timedelta
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels
from scipy.stats import pearsonr
import scipy
import prophet
import warnings
warnings.filterwarnings("ignore")
from matplotlib.font_manager import FontProperties
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
from scipy.optimize import curve_fit
from scipy import stats
import matplotlib.colors as colors
import mapclassify
from libpysal.weights.contiguity import Queen
from libpysal import examples
import geopandas as gpd
from esda.moran import Moran_Local
from splot.esda import lisa_cluster

# %%
font_path = '/Users/carmen/anaconda3/pkgs/r-rmarkdown-2.27-r43hc72bb7e_1/lib/R/library/rmarkdown/rmd/h/bootstrap/css/fonts/RobotoBold.ttf'
font = FontProperties(fname=font_path)

# %%
schema = 'knn'
# schema = 'queen'

if schema == 'queen':
    biasw_mp = pd.read_csv("/Users/carmen/Documents/github/de-bias/DEBIAS_MX/Final_Results_BlockedCV/Inputs/Active_population_bias_queen_p0005.csv", encoding="latin1")
    biasw_fb = pd.read_csv("/Users/carmen/Documents/github/de-bias/DEBIAS_MX/Final_Results_BlockedCV/Inputs/Active_population_bias_queen_tts.csv", encoding="latin1")
else:
    biasw_mp = pd.read_csv("/Users/carmen/Documents/github/de-bias/DEBIAS_MX/Final_Results_BlockedCV/Inputs/Active_population_bias_knn_p0005.csv", encoding="latin1")
    biasw_fb = pd.read_csv("/Users/carmen/Documents/github/de-bias/DEBIAS_MX/Final_Results_BlockedCV/Inputs/Active_population_bias_knn_tts.csv", encoding="latin1")

# %%
biasw_mp = biasw_mp[biasw_mp['bias']!=0].reset_index(drop=True)
biasw_mp = biasw_mp[biasw_mp['bias']>0.965].reset_index(drop=True)
biasw_mp = biasw_mp[biasw_mp['bias_w']!=0].reset_index(drop=True)

# %%
biasw_fb = biasw_fb[biasw_fb['bias']>0].reset_index(drop=True)
# biasw_fb = biasw_fb[biasw_fb['bias']>0.965].reset_index(drop=True)
biasw_fb = biasw_fb[biasw_fb['bias_w']>0].reset_index(drop=True)

# %%
def lin_func(x, a, b):
    return a + x*b

xdata = biasw_mp["bias"].values
ydata = biasw_mp["bias_w"].values
popt, pcov = curve_fit(lin_func, xdata, ydata, p0=[1, 1])
a_hat, b_hat = popt
fit = lin_func(biasw_mp["bias"], a_hat, b_hat)
print(a_hat, b_hat)

# Standard errors are sqrt of diagonal of covariance matrix
perr = np.sqrt(np.diag(pcov))
a_se, b_se = perr
print(a_se, b_se)

# Degrees of freedom: n - number of parameters
n = len(xdata)
p = len(popt)
dof = max(0, n - p)

# t-statistics
t_a = a_hat / a_se
t_b = b_hat / b_se

# Two-sided p-values
p_a = 2 * (1 - stats.t.cdf(np.abs(t_a), dof))
p_b = 2 * (1 - stats.t.cdf(np.abs(t_b), dof))

print(p_a)
print(p_b)
# Out:
# 0.3178103398608479 0.6811892138096779
# 0.011820392210779901 0.011857364975630464
# 0.0
# 0.0

# %%
xdata = biasw_fb["bias"].values
ydata = biasw_fb["bias_w"].values
popt, pcov = curve_fit(lin_func, xdata, ydata, p0=[1, 1])
a_hat, b_hat = popt
fit = lin_func(biasw_fb["bias"], a_hat, b_hat)
print(a_hat, b_hat)

# Standard errors are sqrt of diagonal of covariance matrix
perr = np.sqrt(np.diag(pcov))
a_se, b_se = perr
print(a_se, b_se)

# Degrees of freedom: n - number of parameters
n = len(xdata)
p = len(popt)
dof = max(0, n - p)

# t-statistics
t_a = a_hat / a_se
t_b = b_hat / b_se

# Two-sided p-values
p_a = 2 * (1 - stats.t.cdf(np.abs(t_a), dof))
p_b = 2 * (1 - stats.t.cdf(np.abs(t_b), dof))

print(p_a)
print(p_b)
# Out:
# 0.6447952373728307 0.30457977641530976
# 0.01265301116567987 0.013550261734435203
# 0.0
# 0.0
